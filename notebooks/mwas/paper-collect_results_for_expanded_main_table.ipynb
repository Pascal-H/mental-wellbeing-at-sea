# %% [markdown]
# # Expand the main active speech modelling table
#
# For the revision of the journal publication, the table of "best performing regression models for the prediction of the self-reported mental wellbeing measures" is to be expanded: since there are several different model types and individual speech tasks, the best compromise seems to be to focus on the "Features" column. Here, we distinguish now between "eGeMAPS" and "wav2vec 2.0"-based embeddings.
#
# This notebook respectively iterates over all targets, fetches the best-performing model from the .csv file of each target's "raw" modelling results files, and collects the best performing model. This is done for the eGeMAPS- and the wav2vec-based models respectively.
#
# Before, this was done manually and resulted in `compiled-merged_denoised_noisy-paper.ods`.

# %%
import os
import pandas as pd
import re

path_results_base = "../../results/mwas/composed"

dir_composed = os.path.join(
    path_results_base, "outer_cv_loso_fixed-continuous-surveys_all"
)

# The table will be saved as .csv to the path_results_base directory
file_out = "compiled-merged_denoised_noisy-paper-proper_loso-expanded"

# Map the clean target name to be shown in the publication to the results file
# Format: {"Display Name": ("file_name", "normalization_range")}
dct_targets = {
    "WHO-5": ("who_5_percentage_score_corrected", "raw_0_100-normalized_0_1"),
    "PSS-10": ("pss_10_total_score", "raw_0_40-normalized_0_1"),
    "PHQ-8": ("phq_8_total_score", "raw_0_24-normalized_0_1"),
    "Stress-now": ("stress_current", "raw_0_100-normalized_0_1"),
    "Stress-work": ("stress_work_tasks", "raw_0_100-normalized_0_1"),
}

# %%
# Define the options for the filter criteria string
cur_speech_task = "*"
cur_model = "*"
dct_denoising = {  # cur_denoising
    "Denoised": "filter-snr_tuckey_cutoff_7-clipped_default/denoising-facebook_denoiser-master64-converted_int16_dithering-loudness_normalization-no_loudness_normalization",
    "Noisy": "filter-no_audio_quality_blacklist/denoising-no_denoising-loudness_normalization-no_loudness_normalization",
}
dct_features = {"eGeMAPS": "eGeMAPSv02", "W2V2": "wav2vec2-variant*"}

# %%
# Iterate over all saved tables for each target and condense it to the entries to be
# included in the paper

# DataFrame to collect the best performing model rows per filter iteration
df_best = pd.DataFrame()

for cur_target in dct_targets.keys():
    # Get the value for the target's directory name and normalization range
    cur_target_val, cur_normalization = dct_targets[cur_target]
    cur_df = pd.read_csv(
        os.path.join(dir_composed, "results-" + cur_target_val + "-conf.csv")
    )

    for cur_denoise in dct_denoising.keys():
        cur_denoise_val = dct_denoising[cur_denoise]

        for cur_features in dct_features.keys():
            cur_features_val = dct_features[cur_features]

            str_filter = (
                f"/{cur_target_val}/{cur_normalization}/{cur_speech_task}/cohort-all/{cur_denoise_val}/"
                f"devaice_vad-min_segment_length-0.76-max_segment_length-6.0-segment_start_delay-0.15-segment_end_delay-0.25/"
                f"{cur_features_val}/fixed_test_speakers/type-no_feature_selection/"
                f"sklearn_standard_scaler/personalisation-none/loso/no_inner_cv/no_inner_cv/{cur_model}"
            )

            # Convet into regex pattern to match the placeholder asterisks
            cur_regex_pattern = re.escape(str_filter).replace(r"\*", ".*")
            cur_df_filter = cur_df[cur_df.path.str.match(f"^{cur_regex_pattern}$")]

            # Skip and notify if no matching row was returned
            if cur_df_filter.empty:
                print(f"WARNING: No matching rows for {cur_target} ({cur_target_val}); {cur_denoise}; {cur_features}")
                continue

            # Fetch the row with the best performing model:
            # The highest `ccc_conf_mean`
            cur_best_row = cur_df_filter.sort_values(
                by="ccc_conf_mean", ascending=False
            ).iloc[[0]]

            # Prepare the columns for the paper table processing
            # --> needs the raw labels instead of the nice ones
            cur_best_row["Target"] = cur_target_val
            cur_best_row["Task"] = cur_best_row["path"].str.split("/").str[3]
            # Just capitalise the "features" column
            cur_best_row.rename(columns={"features": "Features"}, inplace=True)
            # For the survey: have hard coded `outer_cv_loso_fixed-continuous-surveys_all`
            # and add "noisy" if no denoising was done
            cur_best_row["Survey"] = "outer_cv_loso_fixed-continuous-surveys_all" + ("-noisy" if cur_denoise == "Noisy" else "")

            df_best = pd.concat([df_best, cur_best_row], ignore_index=True)

# %%
df_best
# Out:
#     ccc_conf_mean  ccc_conf_low  ccc_conf_high  lower_bound_larger_null  \
# 0        0.354083      0.027664       0.567943                     True
# 1        0.348391      0.012134       0.539457                     True
# 2        0.361475      0.031440       0.514476                     True
# 3        0.288002      0.063689       0.481959                     True
# 4        0.082212     -0.099834       0.276044                    False
# 5        0.162778     -0.160369       0.336582                    False
# 6        0.098678     -0.082959       0.261394                    False
# 7        0.117312      0.020579       0.236165                     True
# 8        0.064470     -0.164220       0.318883                    False
# 9        0.194951     -0.037036       0.383240                    False
# 10       0.096189     -0.068599       0.235408                    False
# 11       0.212767     -0.002674       0.377122                    False
# 12       0.112093     -0.056264       0.284551                    False
# 13       0.178202      0.033416       0.313354                     True
# 14       0.151496     -0.142205       0.364083                    False
# 15       0.193889      0.042006       0.320430                     True
# 16       0.237528      0.039963       0.372818                     True
# 17       0.214165      0.040176       0.307733                     True
# 18       0.305632     -0.069905       0.498890                    False
# 19       0.212011      0.031604       0.310605                     True
#
#                                   task  \
# 0             speechtasks-nilago-happy
# 1    speechtasks-sustained_utterance-a
# 2             speechtasks-nilago-happy
# 3           speechtasks-nilago-neutral
# 4   speechtasks-spontaneous-work_tasks
# 5           speechtasks-nilago-neutral
# 6   speechtasks-spontaneous-work_tasks
# 7   speechtasks-spontaneous-work_tasks
# 8    speechtasks-sustained_utterance-a
# 9             speechtasks-nilago-happy
# 10            speechtasks-nilago-happy
# 11            speechtasks-nilago-happy
# 12            speechtasks-nilago-happy
# 13            speechtasks-nilago-happy
# 14   speechtasks-sustained_utterance-a
# 15            speechtasks-nilago-happy
# 16   speechtasks-sustained_utterance-a
# 17            speechtasks-nilago-happy
# 18   speechtasks-sustained_utterance-a
# 19            speechtasks-nilago-happy
#
#                                              Features  pearson_cc-test  \
# 0                                          eGeMAPSv02              NaN
# 1   wav2vec2-variant-wav2vec2-large-robust-ft-libr...              NaN
# 2                                          eGeMAPSv02              NaN
# 3   wav2vec2-variant-wav2vec2-large-robust-ft-libr...              NaN
# 4                                          eGeMAPSv02              NaN
# 5   wav2vec2-variant-wav2vec2-large-robust-ft-libr...              NaN
# 6                                          eGeMAPSv02              NaN
# 7   wav2vec2-variant-wav2vec2-large-robust-12-ft-e...              NaN
# 8                                          eGeMAPSv02              NaN
# 9   wav2vec2-variant-wav2vec2-large-robust-ft-libr...              NaN
# 10                                         eGeMAPSv02              NaN
# 11  wav2vec2-variant-wav2vec2-large-robust-ft-libr...              NaN
# 12                                         eGeMAPSv02              NaN
# 13  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...              NaN
# 14                                         eGeMAPSv02              NaN
# 15  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...         0.125211
# 16                                         eGeMAPSv02              NaN
# 17  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...              NaN
# 18                                         eGeMAPSv02              NaN
# 19  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...              NaN
#
#     concordance_cc-test  mean_squared_error-test  mean_absolute_error-test  \
# 0                   NaN                 0.025808                  0.133634
# 1                   NaN                 0.024404                  0.127393
# 2                   NaN                 0.019839                  0.116789
# 3                   NaN                 0.030445                  0.139364
# 4                   NaN                 0.029347                  0.140539
# 5                   NaN                 0.030705                  0.141387
# 6                   NaN                 0.028052                  0.134900
# 7                   NaN                 0.046500                  0.175782
# 8                   NaN                 0.040698                  0.166915
# 9                   NaN                 0.031299                  0.142139
# 10                  NaN                 0.043269                  0.154492
# 11                  NaN                 0.030301                  0.137211
# 12                  NaN                 0.062916                  0.163610
# 13                  NaN                 0.069857                  0.203120
# 14                  NaN                 0.018938                  0.097325
# 15             0.062868                 0.068044                  0.203536
# 16                  NaN                 0.116526                  0.231741
# 17                  NaN                 0.105242                  0.258228
# 18                  NaN                 0.034446                  0.133929
# 19             0.030876                 0.103765                  0.255831
#
#     ...  mean_squared_error-train-agg-average  \
# 0   ...                          8.271797e-03
# 1   ...                          5.746305e-08
# 2   ...                          5.532489e-03
# 3   ...                          1.169480e-13
# 4   ...                          7.570402e-03
# 5   ...                          2.020112e-14
# 6   ...                          8.130248e-03
# 7   ...                          3.043259e-04
# 8   ...                          4.713939e-03
# 9   ...                          1.039512e-13
# 10  ...                          8.253396e-03
# 11  ...                          6.688269e-14
# 12  ...                          1.201673e-02
# 13  ...                          3.203202e-14
# 14  ...                          6.637340e-03
# 15  ...                          3.257203e-14
# 16  ...                          1.125145e-02
# 17  ...                          3.166079e-14
# 18  ...                          4.303558e-08
# 19  ...                          3.778917e-14
#
#     mean_absolute_error-train-agg-average  pearson_cc-train-agg-median  \
# 0                            7.507299e-02                     0.808070
# 1                            1.738971e-04                     0.999999
# 2                            6.798505e-02                     0.892274
# 3                            2.628740e-07                     1.000000
# 4                            7.292284e-02                     0.798526
# 5                            1.091152e-07                     1.000000
# 6                            7.510810e-02                     0.770091
# 7                            1.345229e-02                     0.992341
# 8                            6.075994e-02                     0.841036
# 9                            2.514588e-07                     1.000000
# 10                           7.293784e-02                     0.775076
# 11                           2.048530e-07                     1.000000
# 12                           6.810119e-02                     0.801452
# 13                           1.421325e-07                     1.000000
# 14                           5.359840e-02                     0.777469
# 15                           1.415972e-07                     1.000000
# 16                           7.627749e-02                     0.810730
# 17                           1.384563e-07                     1.000000
# 18                           1.434209e-04                     0.999999
# 19                           1.493840e-07                     1.000000
#
#     concordance_cc-train-agg-median  mean_squared_error-train-agg-median  \
# 0                          0.783139                         8.541957e-03
# 1                          0.999999                         5.103562e-08
# 2                          0.838539                         5.686809e-03
# 3                          1.000000                         5.467561e-14
# 4                          0.743616                         7.806128e-03
# 5                          1.000000                         1.146670e-14
# 6                          0.693969                         8.619898e-03
# 7                          0.991276                         3.293464e-04
# 8                          0.832387                         5.517887e-03
# 9                          1.000000                         7.120281e-14
# 10                         0.744796                         8.443318e-03
# 11                         1.000000                         6.672254e-14
# 12                         0.769957                         1.194956e-02
# 13                         1.000000                         2.468860e-14
# 14                         0.746984                         6.860370e-03
# 15                         1.000000                         2.195323e-14
# 16                         0.787398                         1.219100e-02
# 17                         1.000000                         2.952177e-14
# 18                         0.999999                         4.233723e-08
# 19                         1.000000                         3.269196e-14
#
#     mean_absolute_error-train-agg-median  \
# 0                           7.674245e-02
# 1                           1.619295e-04
# 2                           6.882290e-02
# 3                           1.769513e-07
# 4                           7.473995e-02
# 5                           8.360411e-08
# 6                           7.791728e-02
# 7                           1.362870e-02
# 8                           6.604461e-02
# 9                           2.041125e-07
# 10                          7.437527e-02
# 11                          2.048222e-07
# 12                          6.731423e-02
# 13                          1.253007e-07
# 14                          5.417778e-02
# 15                          1.153022e-07
# 16                          8.300083e-02
# 17                          1.341821e-07
# 18                          1.361515e-04
# 19                          1.414746e-07
#
#                                                  path  \
# 0   /who_5_percentage_score_corrected/raw_0_100-no...
# 1   /who_5_percentage_score_corrected/raw_0_100-no...
# 2   /who_5_percentage_score_corrected/raw_0_100-no...
# 3   /who_5_percentage_score_corrected/raw_0_100-no...
# 4   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 5   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 6   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 7   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 8   /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 9   /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 10  /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 11  /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 12  /stress_current/raw_0_100-normalized_0_1/speec...
# 13  /stress_current/raw_0_100-normalized_0_1/speec...
# 14  /stress_current/raw_0_100-normalized_0_1/speec...
# 15  /stress_current/raw_0_100-normalized_0_1/speec...
# 16  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 17  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 18  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 19  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
#
#                               Target                                Task  \
# 0   who_5_percentage_score_corrected            speechtasks-nilago-happy
# 1   who_5_percentage_score_corrected   speechtasks-sustained_utterance-a
# 2   who_5_percentage_score_corrected            speechtasks-nilago-happy
# 3   who_5_percentage_score_corrected          speechtasks-nilago-neutral
# 4                 pss_10_total_score  speechtasks-spontaneous-work_tasks
# 5                 pss_10_total_score          speechtasks-nilago-neutral
# 6                 pss_10_total_score  speechtasks-spontaneous-work_tasks
# 7                 pss_10_total_score  speechtasks-spontaneous-work_tasks
# 8                  phq_8_total_score   speechtasks-sustained_utterance-a
# 9                  phq_8_total_score            speechtasks-nilago-happy
# 10                 phq_8_total_score            speechtasks-nilago-happy
# 11                 phq_8_total_score            speechtasks-nilago-happy
# 12                    stress_current            speechtasks-nilago-happy
# 13                    stress_current            speechtasks-nilago-happy
# 14                    stress_current   speechtasks-sustained_utterance-a
# 15                    stress_current            speechtasks-nilago-happy
# 16                 stress_work_tasks   speechtasks-sustained_utterance-a
# 17                 stress_work_tasks            speechtasks-nilago-happy
# 18                 stress_work_tasks   speechtasks-sustained_utterance-a
# 19                 stress_work_tasks            speechtasks-nilago-happy
#
#                                               Survey
# 0         outer_cv_loso_fixed-continuous-surveys_all
# 1         outer_cv_loso_fixed-continuous-surveys_all
# 2   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 3   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 4         outer_cv_loso_fixed-continuous-surveys_all
# 5         outer_cv_loso_fixed-continuous-surveys_all
# 6   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 7   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 8         outer_cv_loso_fixed-continuous-surveys_all
# 9         outer_cv_loso_fixed-continuous-surveys_all
# 10  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 11  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 12        outer_cv_loso_fixed-continuous-surveys_all
# 13        outer_cv_loso_fixed-continuous-surveys_all
# 14  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 15  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 16        outer_cv_loso_fixed-continuous-surveys_all
# 17        outer_cv_loso_fixed-continuous-surveys_all
# 18  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 19  outer_cv_loso_fixed-continuous-surveys_all-noisy
#
# [20 rows x 38 columns]

# %%
df_best.to_csv(os.path.join(path_results_base, file_out+".csv"), index=False)

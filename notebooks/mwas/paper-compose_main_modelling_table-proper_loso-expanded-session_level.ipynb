# %% [markdown]
# # Compose main modelling table for publication
#
# Use the table resulting from `evaluate_session_level_ccc.py` (&rarr; `session_level_analysis/compiled-session_level-paper_configs.csv`) with the best performing model for each target and survey, with eGeMAPS and wav2vec2, and with noisy and denoised data respectively.
# Take that table and convert it to LaTeX source. In the process, change the raw, souce-like strings that e.g., describe the models, into nice and presentable labels. This table can readily be pasted into the LaTeX project of the publication.

# %%
import os
import pandas as pd

# Define the paths
path_results_base = "../../results/mwas/composed/session_level_analysis"
table_paper = "compiled-session_level-paper_configs.csv"

# Construct the full path to the table
table_paper_path = os.path.join(path_results_base, table_paper)

# Read the table from the .ods file
df_paper = pd.read_csv(table_paper_path)
df_paper_raw = df_paper.copy()

# %%
# Insert column "Quality"

# Determine the position of the "Target" column
target_index = df_paper.columns.get_loc("Target")

# Insert the "Quality" column after the "Target" column
df_paper.insert(target_index + 1, "Quality", "")

# Fill the "Quality" column conditionally based on the "Survey" column
df_paper["Quality"] = df_paper["Survey"].apply(
    lambda x: "Noisy" if "noisy" in x else "Denoised"
)

# %%
df_paper
# Out:
#     ccc_conf_mean  ccc_conf_low  ccc_conf_high  lower_bound_larger_null  \
# 0        0.363824     -0.044603       0.590668                    False
# 1        0.238113     -0.015007       0.452820                    False
# 2        0.350369      0.019678       0.515335                     True
# 3        0.340419      0.088999       0.497717                     True
# 4        0.114707     -0.184313       0.315105                    False
# 5        0.172311     -0.122455       0.402716                    False
# 6        0.151166     -0.113080       0.360953                    False
# 7        0.250923      0.058861       0.402575                     True
# 8        0.021402     -0.278219       0.277513                    False
# 9        0.171450     -0.052023       0.345443                    False
# 10       0.106344     -0.060805       0.267038                    False
# 11       0.207540     -0.010477       0.361362                    False
# 12       0.107024     -0.029322       0.310981                    False
# 13       0.175953      0.010493       0.325682                     True
# 14       0.179789     -0.125307       0.422452                    False
# 15       0.198551      0.047913       0.331665                     True
# 16       0.262171     -0.066063       0.422651                    False
# 17       0.214291     -0.004196       0.374055                    False
# 18       0.321858     -0.075174       0.557273                    False
# 19       0.219835     -0.004189       0.379186                    False
#
#                                   task  \
# 0             speechtasks-nilago-happy
# 1    speechtasks-sustained_utterance-a
# 2             speechtasks-nilago-happy
# 3           speechtasks-nilago-neutral
# 4   speechtasks-spontaneous-work_tasks
# 5           speechtasks-nilago-neutral
# 6   speechtasks-spontaneous-work_tasks
# 7   speechtasks-spontaneous-work_tasks
# 8    speechtasks-sustained_utterance-a
# 9             speechtasks-nilago-happy
# 10            speechtasks-nilago-happy
# 11            speechtasks-nilago-happy
# 12            speechtasks-nilago-happy
# 13            speechtasks-nilago-happy
# 14   speechtasks-sustained_utterance-a
# 15            speechtasks-nilago-happy
# 16   speechtasks-sustained_utterance-a
# 17            speechtasks-nilago-happy
# 18   speechtasks-sustained_utterance-a
# 19            speechtasks-nilago-happy
#
#                                              Features  ccc_segment_mean  \
# 0                                          eGeMAPSv02          0.354083
# 1   wav2vec2-variant-wav2vec2-large-robust-ft-libr...          0.348391
# 2                                          eGeMAPSv02          0.361475
# 3   wav2vec2-variant-wav2vec2-large-robust-ft-libr...          0.288002
# 4                                          eGeMAPSv02          0.082212
# 5   wav2vec2-variant-wav2vec2-large-robust-ft-libr...          0.162778
# 6                                          eGeMAPSv02          0.098678
# 7   wav2vec2-variant-wav2vec2-large-robust-12-ft-e...          0.117312
# 8                                          eGeMAPSv02          0.064470
# 9   wav2vec2-variant-wav2vec2-large-robust-ft-libr...          0.194951
# 10                                         eGeMAPSv02          0.096189
# 11  wav2vec2-variant-wav2vec2-large-robust-ft-libr...          0.212767
# 12                                         eGeMAPSv02          0.112093
# 13  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...          0.178202
# 14                                         eGeMAPSv02          0.151496
# 15  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...          0.193889
# 16                                         eGeMAPSv02          0.237528
# 17  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...          0.214165
# 18                                         eGeMAPSv02          0.305632
# 19  wav2vec2-variant-wav2vec2-large-robust-12-ft-e...          0.212011
#
#     ccc_segment_low  ccc_segment_high  concordance_cc-test-agg-average  \
# 0          0.027664          0.567943                         0.363824
# 1          0.012134          0.539457                         0.238113
# 2          0.031440          0.514476                         0.350369
# 3          0.063689          0.481959                         0.340419
# 4         -0.099834          0.276044                         0.114707
# 5         -0.160369          0.336582                         0.172311
# 6         -0.082959          0.261394                         0.151166
# 7          0.020579          0.236165                         0.250923
# 8         -0.164220          0.318883                         0.021402
# 9         -0.037036          0.383240                         0.171450
# 10        -0.068599          0.235408                         0.106344
# 11        -0.002674          0.377122                         0.207540
# 12        -0.056264          0.284551                         0.107024
# 13         0.033416          0.313354                         0.175953
# 14        -0.142205          0.364083                         0.179789
# 15         0.042006          0.320430                         0.198551
# 16         0.039963          0.372818                         0.262171
# 17         0.040176          0.307733                         0.214291
# 18        -0.069905          0.498890                         0.321858
# 19         0.031604          0.310605                         0.219835
#
#                                                  path  \
# 0   /who_5_percentage_score_corrected/raw_0_100-no...
# 1   /who_5_percentage_score_corrected/raw_0_100-no...
# 2   /who_5_percentage_score_corrected/raw_0_100-no...
# 3   /who_5_percentage_score_corrected/raw_0_100-no...
# 4   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 5   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 6   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 7   /pss_10_total_score/raw_0_40-normalized_0_1/sp...
# 8   /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 9   /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 10  /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 11  /phq_8_total_score/raw_0_24-normalized_0_1/spe...
# 12  /stress_current/raw_0_100-normalized_0_1/speec...
# 13  /stress_current/raw_0_100-normalized_0_1/speec...
# 14  /stress_current/raw_0_100-normalized_0_1/speec...
# 15  /stress_current/raw_0_100-normalized_0_1/speec...
# 16  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 17  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 18  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
# 19  /stress_work_tasks/raw_0_100-normalized_0_1/sp...
#
#                               Target   Quality  \
# 0   who_5_percentage_score_corrected  Denoised
# 1   who_5_percentage_score_corrected  Denoised
# 2   who_5_percentage_score_corrected     Noisy
# 3   who_5_percentage_score_corrected     Noisy
# 4                 pss_10_total_score  Denoised
# 5                 pss_10_total_score  Denoised
# 6                 pss_10_total_score     Noisy
# 7                 pss_10_total_score     Noisy
# 8                  phq_8_total_score  Denoised
# 9                  phq_8_total_score  Denoised
# 10                 phq_8_total_score     Noisy
# 11                 phq_8_total_score     Noisy
# 12                    stress_current  Denoised
# 13                    stress_current  Denoised
# 14                    stress_current     Noisy
# 15                    stress_current     Noisy
# 16                 stress_work_tasks  Denoised
# 17                 stress_work_tasks  Denoised
# 18                 stress_work_tasks     Noisy
# 19                 stress_work_tasks     Noisy
#
#                                   Task  \
# 0             speechtasks-nilago-happy
# 1    speechtasks-sustained_utterance-a
# 2             speechtasks-nilago-happy
# 3           speechtasks-nilago-neutral
# 4   speechtasks-spontaneous-work_tasks
# 5           speechtasks-nilago-neutral
# 6   speechtasks-spontaneous-work_tasks
# 7   speechtasks-spontaneous-work_tasks
# 8    speechtasks-sustained_utterance-a
# 9             speechtasks-nilago-happy
# 10            speechtasks-nilago-happy
# 11            speechtasks-nilago-happy
# 12            speechtasks-nilago-happy
# 13            speechtasks-nilago-happy
# 14   speechtasks-sustained_utterance-a
# 15            speechtasks-nilago-happy
# 16   speechtasks-sustained_utterance-a
# 17            speechtasks-nilago-happy
# 18   speechtasks-sustained_utterance-a
# 19            speechtasks-nilago-happy
#
#                                               Survey
# 0         outer_cv_loso_fixed-continuous-surveys_all
# 1         outer_cv_loso_fixed-continuous-surveys_all
# 2   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 3   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 4         outer_cv_loso_fixed-continuous-surveys_all
# 5         outer_cv_loso_fixed-continuous-surveys_all
# 6   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 7   outer_cv_loso_fixed-continuous-surveys_all-noisy
# 8         outer_cv_loso_fixed-continuous-surveys_all
# 9         outer_cv_loso_fixed-continuous-surveys_all
# 10  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 11  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 12        outer_cv_loso_fixed-continuous-surveys_all
# 13        outer_cv_loso_fixed-continuous-surveys_all
# 14  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 15  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 16        outer_cv_loso_fixed-continuous-surveys_all
# 17        outer_cv_loso_fixed-continuous-surveys_all
# 18  outer_cv_loso_fixed-continuous-surveys_all-noisy
# 19  outer_cv_loso_fixed-continuous-surveys_all-noisy

# %%
# Extract the "Model" from the "path" column
df_paper["Model"] = df_paper["path"].str.extract(
    r"/([^/]+)/models/results-compiled\.yaml$"
)

# Replace strings in the "Model" column based on the specified conditions
df_paper["Model"] = df_paper["Model"].apply(
    lambda x: (
        "XGBr"
        if "XGBRegressor" in x
        else (
            "LR"
            if "LinearRegression" in x
            else (
                "SVR"
                if "SVR" in x
                else ("KNNr" if "KNeighborsRegressor-lower" in x else x)
            )
        )
    )
)

# Insert the "Model" column right after the "Task" column
quality_index = df_paper.columns.get_loc("Task")
df_paper.insert(quality_index + 1, "Model", df_paper.pop("Model"))

# %%
# Replace strings in the "Survey" column based on the specified conditions
df_paper["Survey"] = df_paper["Survey"].apply(
    lambda x: (
        "All"
        if "surveys_all" in x
        else ("Daily" if "daily" in x else ("Weekly" if "weekly" in x else x))
    )
)

# %%
# Replace strings in the "Target" column based on the specified conditions
df_paper["Target"] = df_paper["Target"].apply(
    lambda x: (
        "WHO-5"
        if "who_5_percentage_score_corrected" in x
        else (
            "PSS-10"
            if "pss_10_total_score" in x
            else (
                "Stress-now"
                if "stress_current" in x
                else (
                    "PHQ-8"
                    if "phq_8_total_score" in x
                    else ("Stress-work" if "stress_work_tasks" in x else x)
                )
            )
        )
    )
)

# %%
# Replace strings in the "Task" column based on the specified conditions
df_paper["Task"] = df_paper["Task"].apply(
    lambda x: (
        "Read-neutral"
        if "nilago-neutral" in x
        else (
            "Read-happy"
            if "speechtasks-nilago-happy" in x
            else (
                "All"
                if "speechtasks-standardized_tasks" in x
                else (
                    "Counting"
                    if "speechtasks-counting" in x
                    else (
                        "Spontaneous"
                        if "speechtasks-spontaneous-work_tasks" in x
                        else (
                            "Sustained /a/"
                            if "speechtasks-sustained_utterance-a" in x
                            else x
                        )
                    )
                )
            )
        )
    )
)

# %%
# Replace strings in the "Features" column based on the specified conditions
df_paper["Features"] = df_paper["Features"].apply(
    lambda x: (
        "W2V2-LR-LIBRI"
        if "wav2vec2-large-robust-ft-libri-960h-num_hidden_layers-0" in x
        else (
            "W2V2-LR-MSP"
            if "wav2vec2-large-robust-12-ft-emotion-msp-dim-num_hidden_layers-0" in x
            else (
                "W2V2-L-XLSR"
                if "wav2vec2-large-xlsr-53-num_hidden_layers-0" in x
                else ("eGeMAPS" if "eGeMAPSv02" in x else x)
            )
        )
    )
)

# %%
df_paper
# Out:
#     ccc_conf_mean  ccc_conf_low  ccc_conf_high  lower_bound_larger_null  \
# 0        0.363824     -0.044603       0.590668                    False
# 1        0.238113     -0.015007       0.452820                    False
# 2        0.350369      0.019678       0.515335                     True
# 3        0.340419      0.088999       0.497717                     True
# 4        0.114707     -0.184313       0.315105                    False
# 5        0.172311     -0.122455       0.402716                    False
# 6        0.151166     -0.113080       0.360953                    False
# 7        0.250923      0.058861       0.402575                     True
# 8        0.021402     -0.278219       0.277513                    False
# 9        0.171450     -0.052023       0.345443                    False
# 10       0.106344     -0.060805       0.267038                    False
# 11       0.207540     -0.010477       0.361362                    False
# 12       0.107024     -0.029322       0.310981                    False
# 13       0.175953      0.010493       0.325682                     True
# 14       0.179789     -0.125307       0.422452                    False
# 15       0.198551      0.047913       0.331665                     True
# 16       0.262171     -0.066063       0.422651                    False
# 17       0.214291     -0.004196       0.374055                    False
# 18       0.321858     -0.075174       0.557273                    False
# 19       0.219835     -0.004189       0.379186                    False
#
#                                   task       Features  ccc_segment_mean  \
# 0             speechtasks-nilago-happy        eGeMAPS          0.354083
# 1    speechtasks-sustained_utterance-a  W2V2-LR-LIBRI          0.348391
# 2             speechtasks-nilago-happy        eGeMAPS          0.361475
# 3           speechtasks-nilago-neutral  W2V2-LR-LIBRI          0.288002
# 4   speechtasks-spontaneous-work_tasks        eGeMAPS          0.082212
# 5           speechtasks-nilago-neutral  W2V2-LR-LIBRI          0.162778
# 6   speechtasks-spontaneous-work_tasks        eGeMAPS          0.098678
# 7   speechtasks-spontaneous-work_tasks    W2V2-LR-MSP          0.117312
# 8    speechtasks-sustained_utterance-a        eGeMAPS          0.064470
# 9             speechtasks-nilago-happy  W2V2-LR-LIBRI          0.194951
# 10            speechtasks-nilago-happy        eGeMAPS          0.096189
# 11            speechtasks-nilago-happy  W2V2-LR-LIBRI          0.212767
# 12            speechtasks-nilago-happy        eGeMAPS          0.112093
# 13            speechtasks-nilago-happy    W2V2-LR-MSP          0.178202
# 14   speechtasks-sustained_utterance-a        eGeMAPS          0.151496
# 15            speechtasks-nilago-happy    W2V2-LR-MSP          0.193889
# 16   speechtasks-sustained_utterance-a        eGeMAPS          0.237528
# 17            speechtasks-nilago-happy    W2V2-LR-MSP          0.214165
# 18   speechtasks-sustained_utterance-a        eGeMAPS          0.305632
# 19            speechtasks-nilago-happy    W2V2-LR-MSP          0.212011
#
#     ccc_segment_low  ccc_segment_high  concordance_cc-test-agg-average  \
# 0          0.027664          0.567943                         0.363824
# 1          0.012134          0.539457                         0.238113
# 2          0.031440          0.514476                         0.350369
# 3          0.063689          0.481959                         0.340419
# 4         -0.099834          0.276044                         0.114707
# 5         -0.160369          0.336582                         0.172311
# 6         -0.082959          0.261394                         0.151166
# 7          0.020579          0.236165                         0.250923
# 8         -0.164220          0.318883                         0.021402
# 9         -0.037036          0.383240                         0.171450
# 10        -0.068599          0.235408                         0.106344
# 11        -0.002674          0.377122                         0.207540
# 12        -0.056264          0.284551                         0.107024
# 13         0.033416          0.313354                         0.175953
# 14        -0.142205          0.364083                         0.179789
# 15         0.042006          0.320430                         0.198551
# 16         0.039963          0.372818                         0.262171
# 17         0.040176          0.307733                         0.214291
# 18        -0.069905          0.498890                         0.321858
# 19         0.031604          0.310605                         0.219835
#
#                                                  path       Target   Quality  \
# 0   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5  Denoised
# 1   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5  Denoised
# 2   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5     Noisy
# 3   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5     Noisy
# 4   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10  Denoised
# 5   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10  Denoised
# 6   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10     Noisy
# 7   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10     Noisy
# 8   /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8  Denoised
# 9   /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8  Denoised
# 10  /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8     Noisy
# 11  /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8     Noisy
# 12  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now  Denoised
# 13  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now  Denoised
# 14  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now     Noisy
# 15  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now     Noisy
# 16  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work  Denoised
# 17  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work  Denoised
# 18  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work     Noisy
# 19  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work     Noisy
#
#              Task Model Survey
# 0      Read-happy   SVR    All
# 1   Sustained /a/  XGBr    All
# 2      Read-happy   SVR    All
# 3    Read-neutral    LR    All
# 4     Spontaneous   SVR    All
# 5    Read-neutral    LR    All
# 6     Spontaneous   SVR    All
# 7     Spontaneous    LR    All
# 8   Sustained /a/   SVR    All
# 9      Read-happy    LR    All
# 10     Read-happy   SVR    All
# 11     Read-happy    LR    All
# 12     Read-happy  KNNr    All
# 13     Read-happy    LR    All
# 14  Sustained /a/  KNNr    All
# 15     Read-happy    LR    All
# 16  Sustained /a/   SVR    All
# 17     Read-happy    LR    All
# 18  Sustained /a/  XGBr    All
# 19     Read-happy    LR    All

# %%
# Define the custom order for "Survey", "Target", and "Quality"
survey_order = ["All", "Daily", "Weekly"]
target_order = ["WHO-5", "PSS-10", "PHQ-8", "Stress-now", "Stress-work"]
quality_order = ["Denoised", "Noisy"]

# Convert the columns to categorical types with the specified order
df_paper["Survey"] = pd.Categorical(
    df_paper["Survey"], categories=survey_order, ordered=True
)
df_paper["Target"] = pd.Categorical(
    df_paper["Target"], categories=target_order, ordered=True
)
df_paper["Quality"] = pd.Categorical(
    df_paper["Quality"], categories=quality_order, ordered=True
)

# Sort the DataFrame by "Survey", "Target", and "Quality"
# Addition: sort also by features (= eGeMAPS vs. wav2vec), since that factor is included now
df_paper = df_paper.sort_values(by=["Survey", "Target", "Features", "Quality"])

# %%
df_paper
# Out:
#     ccc_conf_mean  ccc_conf_low  ccc_conf_high  lower_bound_larger_null  \
# 1        0.238113     -0.015007       0.452820                    False
# 3        0.340419      0.088999       0.497717                     True
# 0        0.363824     -0.044603       0.590668                    False
# 2        0.350369      0.019678       0.515335                     True
# 5        0.172311     -0.122455       0.402716                    False
# 7        0.250923      0.058861       0.402575                     True
# 4        0.114707     -0.184313       0.315105                    False
# 6        0.151166     -0.113080       0.360953                    False
# 9        0.171450     -0.052023       0.345443                    False
# 11       0.207540     -0.010477       0.361362                    False
# 8        0.021402     -0.278219       0.277513                    False
# 10       0.106344     -0.060805       0.267038                    False
# 13       0.175953      0.010493       0.325682                     True
# 15       0.198551      0.047913       0.331665                     True
# 12       0.107024     -0.029322       0.310981                    False
# 14       0.179789     -0.125307       0.422452                    False
# 17       0.214291     -0.004196       0.374055                    False
# 19       0.219835     -0.004189       0.379186                    False
# 16       0.262171     -0.066063       0.422651                    False
# 18       0.321858     -0.075174       0.557273                    False
#
#                                   task       Features  ccc_segment_mean  \
# 1    speechtasks-sustained_utterance-a  W2V2-LR-LIBRI          0.348391
# 3           speechtasks-nilago-neutral  W2V2-LR-LIBRI          0.288002
# 0             speechtasks-nilago-happy        eGeMAPS          0.354083
# 2             speechtasks-nilago-happy        eGeMAPS          0.361475
# 5           speechtasks-nilago-neutral  W2V2-LR-LIBRI          0.162778
# 7   speechtasks-spontaneous-work_tasks    W2V2-LR-MSP          0.117312
# 4   speechtasks-spontaneous-work_tasks        eGeMAPS          0.082212
# 6   speechtasks-spontaneous-work_tasks        eGeMAPS          0.098678
# 9             speechtasks-nilago-happy  W2V2-LR-LIBRI          0.194951
# 11            speechtasks-nilago-happy  W2V2-LR-LIBRI          0.212767
# 8    speechtasks-sustained_utterance-a        eGeMAPS          0.064470
# 10            speechtasks-nilago-happy        eGeMAPS          0.096189
# 13            speechtasks-nilago-happy    W2V2-LR-MSP          0.178202
# 15            speechtasks-nilago-happy    W2V2-LR-MSP          0.193889
# 12            speechtasks-nilago-happy        eGeMAPS          0.112093
# 14   speechtasks-sustained_utterance-a        eGeMAPS          0.151496
# 17            speechtasks-nilago-happy    W2V2-LR-MSP          0.214165
# 19            speechtasks-nilago-happy    W2V2-LR-MSP          0.212011
# 16   speechtasks-sustained_utterance-a        eGeMAPS          0.237528
# 18   speechtasks-sustained_utterance-a        eGeMAPS          0.305632
#
#     ccc_segment_low  ccc_segment_high  concordance_cc-test-agg-average  \
# 1          0.012134          0.539457                         0.238113
# 3          0.063689          0.481959                         0.340419
# 0          0.027664          0.567943                         0.363824
# 2          0.031440          0.514476                         0.350369
# 5         -0.160369          0.336582                         0.172311
# 7          0.020579          0.236165                         0.250923
# 4         -0.099834          0.276044                         0.114707
# 6         -0.082959          0.261394                         0.151166
# 9         -0.037036          0.383240                         0.171450
# 11        -0.002674          0.377122                         0.207540
# 8         -0.164220          0.318883                         0.021402
# 10        -0.068599          0.235408                         0.106344
# 13         0.033416          0.313354                         0.175953
# 15         0.042006          0.320430                         0.198551
# 12        -0.056264          0.284551                         0.107024
# 14        -0.142205          0.364083                         0.179789
# 17         0.040176          0.307733                         0.214291
# 19         0.031604          0.310605                         0.219835
# 16         0.039963          0.372818                         0.262171
# 18        -0.069905          0.498890                         0.321858
#
#                                                  path       Target   Quality  \
# 1   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5  Denoised
# 3   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5     Noisy
# 0   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5  Denoised
# 2   /who_5_percentage_score_corrected/raw_0_100-no...        WHO-5     Noisy
# 5   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10  Denoised
# 7   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10     Noisy
# 4   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10  Denoised
# 6   /pss_10_total_score/raw_0_40-normalized_0_1/sp...       PSS-10     Noisy
# 9   /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8  Denoised
# 11  /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8     Noisy
# 8   /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8  Denoised
# 10  /phq_8_total_score/raw_0_24-normalized_0_1/spe...        PHQ-8     Noisy
# 13  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now  Denoised
# 15  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now     Noisy
# 12  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now  Denoised
# 14  /stress_current/raw_0_100-normalized_0_1/speec...   Stress-now     Noisy
# 17  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work  Denoised
# 19  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work     Noisy
# 16  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work  Denoised
# 18  /stress_work_tasks/raw_0_100-normalized_0_1/sp...  Stress-work     Noisy
#
#              Task Model Survey
# 1   Sustained /a/  XGBr    All
# 3    Read-neutral    LR    All
# 0      Read-happy   SVR    All
# 2      Read-happy   SVR    All
# 5    Read-neutral    LR    All
# 7     Spontaneous    LR    All
# 4     Spontaneous   SVR    All
# 6     Spontaneous   SVR    All
# 9      Read-happy    LR    All
# 11     Read-happy    LR    All
# 8   Sustained /a/   SVR    All
# 10     Read-happy   SVR    All
# 13     Read-happy    LR    All
# 15     Read-happy    LR    All
# 12     Read-happy  KNNr    All
# 14  Sustained /a/  KNNr    All
# 17     Read-happy    LR    All
# 19     Read-happy    LR    All
# 16  Sustained /a/   SVR    All
# 18  Sustained /a/  XGBr    All

# %%
# Summarize the columns "ccc_conf_mean", "ccc_conf_low", and "ccc_conf_high" into one column "CCC"
# --> these are the session-level values; the segment-level values reside in "ccc_segment_mean" etc.
df_paper["CCC"] = df_paper.apply(
    # Add math mode through `$` for nice display in LaTeX
    lambda row: f"${row['ccc_conf_mean']:.3f} ({row['ccc_conf_low']:.3f} - {row['ccc_conf_high']:.3f})$",
    axis=1,
)

# Add an asterisk to the end of the "CCC" strings in all rows where "lower_bound_larger_null" is True
df_paper.loc[df_paper["lower_bound_larger_null"] == True, "CCC"] += "*"

# Insert the "CCC" column right after the "Quality" column
quality_index = df_paper.columns.get_loc("Quality")
df_paper.insert(quality_index + 1, "CCC", df_paper.pop("CCC"))

# %%
# Just keep the columns relevant for the LaTeX output in their designated order
df_paper_full = df_paper.copy()
df_paper = df_paper[["Target", "Quality", "CCC", "Task", "Model", "Features"]]

# %%
# The following formatting automations seem not to work reliable (the "Survey")
# column was dropped anyways; so: manually set the best performing model
# in bold face and manially set hlines.

# %%
# Function to highlight the best performing model's "CCC" value per "Survey" section
def highlight_best_ccc(df):
    # Create a helper column to extract the numeric part of "CCC"
    df["CCC_float"] = df["CCC"].str.split().str[0].astype(float)

    for survey in df["Survey"].unique():
        survey_df = df[df["Survey"] == survey]
        max_ccc_index = survey_df["CCC_float"].idxmax()
        df.at[max_ccc_index, "CCC"] = f"\\textbf{{{df.at[max_ccc_index, 'CCC']}}}"

    # Drop the helper column
    df = df.drop(columns=["CCC_float"])

    return df


# Highlight the best performing model's "CCC" value per "Survey" section
# df_paper = highlight_best_ccc(df_paper)

# %%
# Add horizontal lines at the transitions between "Survey" categories
def add_horizontal_lines(df):
    latex_str = df.to_latex(index=False)
    lines = latex_str.splitlines()
    new_lines = []
    df_index = 0  # Initialize DataFrame row index
    for i, line in enumerate(lines):
        new_lines.append(line)
        # Check if the current line is a data line (not a header or formatting line)
        if (
            i > 3 and i < len(lines) - 1
        ):  # Skip the first three lines (header and \midrule)
            if df_index < len(df) - 1:  # Ensure df_index is within bounds
                prev_survey = df.iloc[df_index]["Survey"]
                curr_survey = df.iloc[df_index + 1]["Survey"]
                if prev_survey != curr_survey:
                    new_lines.append("\\hline")
            df_index += 1  # Increment DataFrame row index only for data lines
    return "\n".join(new_lines)


# Export the DataFrame to LaTeX format with horizontal lines
# latex_code = add_horizontal_lines(df_paper)

# %%
df_paper
# Out:
#          Target   Quality                       CCC           Task Model  \
# 1         WHO-5  Denoised  $0.238 (-0.015 - 0.453)$  Sustained /a/  XGBr
# 3         WHO-5     Noisy  $0.340 (0.089 - 0.498)$*   Read-neutral    LR
# 0         WHO-5  Denoised  $0.364 (-0.045 - 0.591)$     Read-happy   SVR
# 2         WHO-5     Noisy  $0.350 (0.020 - 0.515)$*     Read-happy   SVR
# 5        PSS-10  Denoised  $0.172 (-0.122 - 0.403)$   Read-neutral    LR
# 7        PSS-10     Noisy  $0.251 (0.059 - 0.403)$*    Spontaneous    LR
# 4        PSS-10  Denoised  $0.115 (-0.184 - 0.315)$    Spontaneous   SVR
# 6        PSS-10     Noisy  $0.151 (-0.113 - 0.361)$    Spontaneous   SVR
# 9         PHQ-8  Denoised  $0.171 (-0.052 - 0.345)$     Read-happy    LR
# 11        PHQ-8     Noisy  $0.208 (-0.010 - 0.361)$     Read-happy    LR
# 8         PHQ-8  Denoised  $0.021 (-0.278 - 0.278)$  Sustained /a/   SVR
# 10        PHQ-8     Noisy  $0.106 (-0.061 - 0.267)$     Read-happy   SVR
# 13   Stress-now  Denoised  $0.176 (0.010 - 0.326)$*     Read-happy    LR
# 15   Stress-now     Noisy  $0.199 (0.048 - 0.332)$*     Read-happy    LR
# 12   Stress-now  Denoised  $0.107 (-0.029 - 0.311)$     Read-happy  KNNr
# 14   Stress-now     Noisy  $0.180 (-0.125 - 0.422)$  Sustained /a/  KNNr
# 17  Stress-work  Denoised  $0.214 (-0.004 - 0.374)$     Read-happy    LR
# 19  Stress-work     Noisy  $0.220 (-0.004 - 0.379)$     Read-happy    LR
# 16  Stress-work  Denoised  $0.262 (-0.066 - 0.423)$  Sustained /a/   SVR
# 18  Stress-work     Noisy  $0.322 (-0.075 - 0.557)$  Sustained /a/  XGBr
#
#          Features
# 1   W2V2-LR-LIBRI
# 3   W2V2-LR-LIBRI
# 0         eGeMAPS
# 2         eGeMAPS
# 5   W2V2-LR-LIBRI
# 7     W2V2-LR-MSP
# 4         eGeMAPS
# 6         eGeMAPS
# 9   W2V2-LR-LIBRI
# 11  W2V2-LR-LIBRI
# 8         eGeMAPS
# 10        eGeMAPS
# 13    W2V2-LR-MSP
# 15    W2V2-LR-MSP
# 12        eGeMAPS
# 14        eGeMAPS
# 17    W2V2-LR-MSP
# 19    W2V2-LR-MSP
# 16        eGeMAPS
# 18        eGeMAPS

# %%
latex_code = df_paper.to_latex(index=False)
print(latex_code)
# Out:
# \begin{tabular}{llllll}
# \toprule
# Target & Quality & CCC & Task & Model & Features \\
# \midrule
# WHO-5 & Denoised & $0.238 (-0.015 - 0.453)$ & Sustained /a/ & XGBr & W2V2-LR-LIBRI \\
# WHO-5 & Noisy & $0.340 (0.089 - 0.498)$* & Read-neutral & LR & W2V2-LR-LIBRI \\
# WHO-5 & Denoised & $0.364 (-0.045 - 0.591)$ & Read-happy & SVR & eGeMAPS \\
# WHO-5 & Noisy & $0.350 (0.020 - 0.515)$* & Read-happy & SVR & eGeMAPS \\
# PSS-10 & Denoised & $0.172 (-0.122 - 0.403)$ & Read-neutral & LR & W2V2-LR-LIBRI \\
# PSS-10 & Noisy & $0.251 (0.059 - 0.403)$* & Spontaneous & LR & W2V2-LR-MSP \\
# PSS-10 & Denoised & $0.115 (-0.184 - 0.315)$ & Spontaneous & SVR & eGeMAPS \\
# PSS-10 & Noisy & $0.151 (-0.113 - 0.361)$ & Spontaneous & SVR & eGeMAPS \\
# PHQ-8 & Denoised & $0.171 (-0.052 - 0.345)$ & Read-happy & LR & W2V2-LR-LIBRI \\
# PHQ-8 & Noisy & $0.208 (-0.010 - 0.361)$ & Read-happy & LR & W2V2-LR-LIBRI \\
# PHQ-8 & Denoised & $0.021 (-0.278 - 0.278)$ & Sustained /a/ & SVR & eGeMAPS \\
# PHQ-8 & Noisy & $0.106 (-0.061 - 0.267)$ & Read-happy & SVR & eGeMAPS \\
# Stress-now & Denoised & $0.176 (0.010 - 0.326)$* & Read-happy & LR & W2V2-LR-MSP \\
# Stress-now & Noisy & $0.199 (0.048 - 0.332)$* & Read-happy & LR & W2V2-LR-MSP \\
# Stress-now & Denoised & $0.107 (-0.029 - 0.311)$ & Read-happy & KNNr & eGeMAPS \\
# Stress-now & Noisy & $0.180 (-0.125 - 0.422)$ & Sustained /a/ & KNNr & eGeMAPS \\
# Stress-work & Denoised & $0.214 (-0.004 - 0.374)$ & Read-happy & LR & W2V2-LR-MSP \\
# Stress-work & Noisy & $0.220 (-0.004 - 0.379)$ & Read-happy & LR & W2V2-LR-MSP \\
# Stress-work & Denoised & $0.262 (-0.066 - 0.423)$ & Sustained /a/ & SVR & eGeMAPS \\
# Stress-work & Noisy & $0.322 (-0.075 - 0.557)$ & Sustained /a/ & XGBr & eGeMAPS \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Manually mark the best-performing model with `\mathbf{}` and add vertical lines and spaces for better readability:
# After each feature set bundle (transitioning from wav2vec2 to eGeMAPS): add `\addlinespace[0.25em]`; after each target, add `\hline`.
